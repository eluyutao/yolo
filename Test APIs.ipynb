# %%
from pandas_datareader.yahoo.options import Options

# %%
import pandas_datareader.data as web
from pandas_datareader.yahoo.headers import DEFAULT_HEADERS
import datetime
import requests_cache
expire_after = datetime.timedelta(days=3)
session = requests_cache.CachedSession(cache_name='cache', backend='sqlite', expire_after=expire_after)
session.headers = DEFAULT_HEADERS

# %%
session.headers
# Out:
# {'Connection': 'keep-alive',
#  'Expires': '-1',
#  'Upgrade-Insecure-Requests': '1',
#  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

# %%
aapl = Options('aapl', session)  # Create object
# aapl.calls  # will give an AttributeError
aapl.get_options_data()  # Get data and set ivars
# aapl.calls  # Doesn't throw AttributeError
# Out:
#                                              Last   Bid    Ask       Chg  \
# Strike Expiry     Type Symbol
# 105.0  2022-02-11 call AAPL220211C00105000  67.40  66.4  66.95 -0.729996
#                   put  AAPL220211P00105000   0.01   0.0   0.01  0.000000
# 110.0  2022-02-11 call AAPL220211C00110000  64.26  61.4  61.95  0.000000
#                   put  AAPL220211P00110000   0.01   0.0   0.01  0.000000
# 115.0  2022-02-11 call AAPL220211C00115000  59.84  56.4  56.95  0.000000
# ...                                           ...   ...    ...       ...
# 235.0  2022-02-11 call AAPL220211C00235000   0.03   0.0   0.01  0.000000
# 240.0  2022-02-11 call AAPL220211C00240000   0.01   0.0   0.03  0.000000
# 245.0  2022-02-11 call AAPL220211C00245000   0.01   0.0   0.01  0.000000
# 250.0  2022-02-11 call AAPL220211C00250000   0.01   0.0   0.01  0.000000
#                   put  AAPL220211P00250000  87.00  77.1  79.70  0.000000
#
#                                               PctChg     Vol  Open_Int  \
# Strike Expiry     Type Symbol
# 105.0  2022-02-11 call AAPL220211C00105000 -1.071475     6.0      31.0
#                   put  AAPL220211P00105000  0.000000  5114.0    1877.0
# 110.0  2022-02-11 call AAPL220211C00110000  0.000000     1.0       5.0
#                   put  AAPL220211P00110000  0.000000     7.0    1392.0
# 115.0  2022-02-11 call AAPL220211C00115000  0.000000     2.0       2.0
# ...                                              ...     ...       ...
# 235.0  2022-02-11 call AAPL220211C00235000  0.000000    10.0      59.0
# 240.0  2022-02-11 call AAPL220211C00240000  0.000000     1.0      87.0
# 245.0  2022-02-11 call AAPL220211C00245000  0.000000    10.0     207.0
# 250.0  2022-02-11 call AAPL220211C00250000  0.000000     2.0      41.0
#                   put  AAPL220211P00250000  0.000000     2.0       0.0
#
#                                                   IV  Root  IsNonstandard  \
# Strike Expiry     Type Symbol
# 105.0  2022-02-11 call AAPL220211C00105000  1.656252  AAPL          False
#                   put  AAPL220211P00105000  1.500002  AAPL          False
# 110.0  2022-02-11 call AAPL220211C00110000  1.500002  AAPL          False
#                   put  AAPL220211P00110000  1.375003  AAPL          False
# 115.0  2022-02-11 call AAPL220211C00115000  1.359378  AAPL          False
# ...                                              ...   ...            ...
# 235.0  2022-02-11 call AAPL220211C00235000  0.968750  AAPL          False
# 240.0  2022-02-11 call AAPL220211C00240000  1.125004  AAPL          False
# 245.0  2022-02-11 call AAPL220211C00245000  1.062505  AAPL          False
# 250.0  2022-02-11 call AAPL220211C00250000  1.125004  AAPL          False
#                   put  AAPL220211P00250000  1.429690  AAPL          False
#
#                                            Underlying  Underlying_Price  \
# Strike Expiry     Type Symbol
# 105.0  2022-02-11 call AAPL220211C00105000       AAPL            172.38
#                   put  AAPL220211P00105000       AAPL            172.38
# 110.0  2022-02-11 call AAPL220211C00110000       AAPL            172.38
#                   put  AAPL220211P00110000       AAPL            172.38
# 115.0  2022-02-11 call AAPL220211C00115000       AAPL            172.38
# ...                                               ...               ...
# 235.0  2022-02-11 call AAPL220211C00235000       AAPL            172.38
# 240.0  2022-02-11 call AAPL220211C00240000       AAPL            172.38
# 245.0  2022-02-11 call AAPL220211C00245000       AAPL            172.38
# 250.0  2022-02-11 call AAPL220211C00250000       AAPL            172.38
#                   put  AAPL220211P00250000       AAPL            172.38
#
#                                                     Quote_Time  \
# Strike Expiry     Type Symbol
# 105.0  2022-02-11 call AAPL220211C00105000 2022-02-08 00:59:55
#                   put  AAPL220211P00105000 2022-02-08 00:59:55
# 110.0  2022-02-11 call AAPL220211C00110000 2022-02-08 00:59:55
#                   put  AAPL220211P00110000 2022-02-08 00:59:55
# 115.0  2022-02-11 call AAPL220211C00115000 2022-02-08 00:59:55
# ...                                                        ...
# 235.0  2022-02-11 call AAPL220211C00235000 2022-02-08 00:59:55
# 240.0  2022-02-11 call AAPL220211C00240000 2022-02-08 00:59:55
# 245.0  2022-02-11 call AAPL220211C00245000 2022-02-08 00:59:55
# 250.0  2022-02-11 call AAPL220211C00250000 2022-02-08 00:59:55
#                   put  AAPL220211P00250000 2022-02-08 00:59:55
#
#                                                Last_Trade_Date  \
# Strike Expiry     Type Symbol
# 105.0  2022-02-11 call AAPL220211C00105000 2022-02-07 20:33:02
#                   put  AAPL220211P00105000 2022-02-07 17:01:49
# 110.0  2022-02-11 call AAPL220211C00110000 2022-02-03 20:58:34
#                   put  AAPL220211P00110000 2022-02-07 15:28:31
# 115.0  2022-02-11 call AAPL220211C00115000 2022-02-03 19:30:55
# ...                                                        ...
# 235.0  2022-02-11 call AAPL220211C00235000 2022-01-26 19:04:25
# 240.0  2022-02-11 call AAPL220211C00240000 2022-01-27 20:49:09
# 245.0  2022-02-11 call AAPL220211C00245000 2022-01-28 20:37:52
# 250.0  2022-02-11 call AAPL220211C00250000 2022-02-07 20:52:13
#                   put  AAPL220211P00250000 2022-01-28 14:47:18
#
#                                                                                          JSON
# Strike Expiry     Type Symbol
# 105.0  2022-02-11 call AAPL220211C00105000  {'contractSymbol': 'AAPL220211C00105000', 'str...
#                   put  AAPL220211P00105000  {'contractSymbol': 'AAPL220211P00105000', 'str...
# 110.0  2022-02-11 call AAPL220211C00110000  {'contractSymbol': 'AAPL220211C00110000', 'str...
#                   put  AAPL220211P00110000  {'contractSymbol': 'AAPL220211P00110000', 'str...
# 115.0  2022-02-11 call AAPL220211C00115000  {'contractSymbol': 'AAPL220211C00115000', 'str...
# ...                                                                                       ...
# 235.0  2022-02-11 call AAPL220211C00235000  {'contractSymbol': 'AAPL220211C00235000', 'str...
# 240.0  2022-02-11 call AAPL220211C00240000  {'contractSymbol': 'AAPL220211C00240000', 'str...
# 245.0  2022-02-11 call AAPL220211C00245000  {'contractSymbol': 'AAPL220211C00245000', 'str...
# 250.0  2022-02-11 call AAPL220211C00250000  {'contractSymbol': 'AAPL220211C00250000', 'str...
#                   put  AAPL220211P00250000  {'contractSymbol': 'AAPL220211P00250000', 'str...
#
# [87 rows x 15 columns]
